# %% [markdown]
# This notebook is to generate the new merged datframe and save it to my desktop.

# %% [markdown]
# To load the dataset only one time. (Takes 1min 23 sec)
# The full dataset is called df, and is used in later code blocks.
# Run the whole script to load the correct way.
#
# Set boundary to lead the correct merged_df further down!

# %%
from LoadingDataset import *

df = loading_dataframe() 

print(df)
# Out:
# --Start loading dataset--
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Track_363'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/frame.py:4573, in DataFrame._set_value(self, index, col, value, takeable)
#    4572     icol = self.columns.get_loc(col)
# -> 4573     iindex = self.index.get_loc(index)
#    4574 self._mgr.column_setitem(icol, iindex, value, inplace_only=True)
#
# File ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#
# KeyError: 'Track_363'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sm/65sm9yyj6yqghzp3hzvwcbsr0000gn/T/ipykernel_85343/2473922185.py in ?()
#       1 from LoadingDataset import *
#       2
# ----> 3 df = loading_dataframe()
#       4
#       5 print(df)
#
# ~/Desktop/Thesis_2.0/code_2/mosquito_data_refinement/oktober_format/LoadingDataset.py in ?()
#     108 def loading_dataframe():
# --> 109     df = loading(path_matlab_file1)
#     110     return df
#
# ~/Desktop/Thesis_2.0/code_2/mosquito_data_refinement/oktober_format/LoadingDataset.py in ?(path_matlab_file)
#      97                         y_tuple = tuple(filtered_y)
#      98                         z_tuple = tuple(filtered_z)
#      99                         time_tuple = tuple(filtered_time)
#     100
# --> 101                         dictionary[trial_key].at[f'Track_{track_number + 1}', 'x'] = x_tuple
#     102                         dictionary[trial_key].at[f'Track_{track_number + 1}', 'y'] = y_tuple
#     103                         dictionary[trial_key].at[f'Track_{track_number + 1}', 'z'] = z_tuple
#     104                         dictionary[trial_key].at[f'Track_{track_number + 1}', 'time'] = time_tuple
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, key, value)
#    2599
#    2600             self.obj.loc[key] = value
#    2601             return
#    2602
# -> 2603         return super().__setitem__(key, value)
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, key, value)
#    2539         key = list(self._convert_key(key))
#    2540         if len(key) != self.ndim:
#    2541             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2542
# -> 2543         self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, index, col, value, takeable)
#    4582             # set using a non-recursive method & reset the cache
#    4583             if takeable:
#    4584                 self.iloc[index, col] = value
#    4585             else:
# -> 4586                 self.loc[index, col] = value
#    4587             self._item_cache.pop(col, None)
#    4588
#    4589         except InvalidIndexError as ii_err:
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, key, value)
#     908         indexer = self._get_setitem_indexer(key)
#     909         self._has_valid_setitem_indexer(key)
#     910
#     911         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912         iloc._setitem_with_indexer(indexer, value, self.name)
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, indexer, value, name)
#    1912                     #  this is valid even if the index has duplicates.
#    1913                     taker = np.arange(len(index) + 1, dtype=np.intp)
#    1914                     taker[-1] = -1
#    1915                     reindexers = {i: (labels, taker)}
# -> 1916                     new_obj = self.obj._reindex_with_indexers(
#    1917                         reindexers, allow_dups=True
#    1918                     )
#    1919                     self.obj._mgr = new_obj._mgr
#
# ~/anaconda3/envs/mosquito_env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, reindexers, fill_value, copy, allow_dups)
#    5721             and new_data is self._mgr
#    5722             and not using_copy_on_write()
#    5723         ):
#    5724             new_data = new_data.copy(deep=copy)
# -> 5725         elif using_copy_on_write() and new_data is self._mgr:
#    5726             new_data = new_data.copy(deep=False)
#    5727
#    5728         return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#
# KeyboardInterrupt:

# %% [markdown]
# Acces a track.
#
# x --> df['Trial_1'].loc['Track_1'][0] or df['Trial_1'].loc['Track_1', 'x']
#
# y --> df['Trial_1'].loc['Track_1'][1] or df['Trial_1'].loc['Track_1', 'z']
#
# z --> df['Trial_1'].loc['Track_1'][2] or df['Trial_1'].loc['Track_1', 'y']
#
# time --> df['Trial_1'].loc['Track_1'][3] or df['Trial_1'].loc['Track_1', 'time']

# %%
df['Trial_10'].loc['Track_6']
# Out:
# x       (-0.4802723191159874, -0.47263961920878894, -0...
# y       (-0.028486223927734772, -0.02355766121061059, ...
# z       (0.5484372752921228, 0.5438705716555217, 0.539...
# time    (199.0888888888889, 199.1, 199.11111111111111,...
# Name: Track_6, dtype: object

# %% [markdown]
# Create a joblib of the dataframe (1m 44s)

# %%
import joblib 
import os

dataset_path = '/Users/nubia/Desktop/Thesis_2.0/dataset'
save_path = os.path.join(dataset_path, "df.joblib")
joblib.dump(df, save_path)

print(f"Data saved to: {save_path}")
# Out:
# Data saved to: /Users/nubia/Desktop/Thesis_2.0/dataset/df.joblib

# %% [markdown]
# Create merged_df from here onward.
#
# Add the boundary and radius (max distance of two tracks) data here!
#
# RUN FROM THIS CELL DOWN

# %%
import joblib
import numpy as np
import pandas as pd
import os
df_path = '/Users/nubia/Desktop/Thesis_2.0/dataset/df.joblib'
df = joblib.load(df_path)

# %%
boundary1 = 0.01 # set boundary value here (0.01 - 0.04)
radius1 = 0.02 # set radius value here (0.01 - 0.04)

file_name = f"merged_df_boundary_{boundary1}_radius_{radius1}.joblib"

# %% [markdown]
# Added column that tells if the track has landed.
# To call the landed column: df['Trial_1']['landed']
# Loop trhough this coumn: for track_name, landed_status in df['Trial_1']['landed'].items():
# To ask if a specific track is landed: df['Trial_1'].loc['Track_1', 'landed'] --> true or false.
#
# Same goes for take-off

# %%
from CommonFunctions import landing_area_point 
for trial_num in range(1,65): 
    landed = []
    for track_name, track_data in df[f'Trial_{trial_num}'].iterrows():
        # Get last position and time values
        last_x = track_data['x'][-1]
        last_y = track_data['y'][-1]
        last_z = track_data['z'][-1]
        
        # Check if landed
        landed.append(landing_area_point(last_x, last_y, last_z, boundary =boundary1))
        
    # Add the 'landed' column to the DataFrame (same value for all rows)
    trial_df = df[f'Trial_{trial_num}']
    trial_df['landed'] = landed
    df[f'Trial_{trial_num}'] = trial_df

for track_name, landed_status in df['Trial_1']['landed'].items():       
    if landed_status: 
        print(track_name, landed_status)
# Out:
# Track_550 True
# Track_568 True
# Track_664 True
# Track_687 True
# Track_688 True

# %%
from CommonFunctions import landing_area_point
for trial_num in range(1,65): 
    take_off = []
    for track_name, track_data in df[f'Trial_{trial_num}'].iterrows():
        # Get last position and time values
        first_x = track_data['x'][0]
        first_y = track_data['y'][0]
        first_z = track_data['z'][0]
        
        # Check if landed
        take_off.append(landing_area_point(first_x, first_y, first_z, boundary =boundary1))
        
    # Add the 'landed' column to the DataFrame (same value for all rows)
    trial_df = df[f'Trial_{trial_num}']
    trial_df['take_off'] = take_off
    df[f'Trial_{trial_num}'] = trial_df

count = 0 
for track_name, take_off_status in df['Trial_1']['take_off'].items():       
    if take_off_status: 
        count += 1

if count == 42: 
    print('This function works for Trial 1')

# %% [markdown]
# Generating the pairs connecting the landings with the take-offs.
# Per landing it checks if there is a take-off assosiated with it within the radius boundary.
# If multiple points are found, it chooses the closest take-off to the landing point.
# If this take-off is already used once, it checks if the pair has a shorter distance between them. If so, the pair gets replaced.
#
# Can be optimised by checking the next point, if a point does not get replaced. ! (Not done that just yet)

# %%
def generating_pairs(trial_num, radius = 0.2):  
        pairs=[]
        for track_name, track_data in df[f'Trial_{trial_num}'].iterrows():
            potential_pairs = []
            if track_data['landed']: 
                last_x, last_y, last_z, last_time = track_data['x'][-1], track_data['y'][-1], track_data['z'][-1], track_data['time'][-1]
                for track_name2, track_data2 in df[f'Trial_{trial_num}'].iterrows():
                    if track_data2['take_off']: 
                        first_x, first_y, first_z, first_time = track_data2['x'][0], track_data2['y'][0], track_data2['z'][0], track_data2['time'][0]
                        dx, dy, dz, dtime = (first_x - last_x), (first_y - last_y), (first_z - last_z), (first_time - last_time)
                        distance = np.sqrt((dx ** 2) + (dy ** 2) + (dz ** 2))
                        if (distance < radius and dtime > 0):
                            potential_pairs.append((distance,track_name, track_name2))
            if potential_pairs: 
                closest_pair = potential_pairs[0] # only choose the closest take-off to the landing point
                if pairs: 
                    found_match = False
                    for i, pair in enumerate(pairs): 
                        if closest_pair[2] == pair[2]: # check if there are similar take-off tracks already saved
                            found_match = True
                            if closest_pair[0] < pair[0]: # check if new pair as a shorter distance then existing pair in pairs list. 
                                pairs[i] = closest_pair # replacing existing pair with newer pair. 
                    if not found_match: 
                        pairs.append(closest_pair)
                else: 
                    pairs.append(closest_pair)
        return pairs

#testing if the function works: testing for duplicate tracks in the list
trial_num = 5
landing_list, take_off_list = [], []
for pair in generating_pairs(trial_num): 
    distance, track_name1, track_name2 = pair 
    landing_list.append(track_name1)
    take_off_list.append(track_name1)
duplicates_landing = {t for t in landing_list if landing_list.count(t) > 1}
duplicates_take_off = {t for t in take_off_list if take_off_list.count(t) > 1}
if duplicates_landing or duplicates_take_off: 
    print(f'Not working: There are duplicate tracks')
    if duplicates_landing: 
        print('Fault in landings')
    else: 
        print('fault in take-offs')
else: 
    print('Function working: There are no duplicates')
# Out:
# Function working: There are no duplicates

# %% [markdown]
# Now check iff the landings also begin in a take_off we found earlyer. Or that a take_off ands in a landing we found earlyer.
# I make a chain of tracks that connect together.

# %%
def generating_pairs_complex(trial_num, radius = 0.2): 
    pairs = generating_pairs(trial_num, radius = radius)
    connection_map = {landing: takeoff for _, landing, takeoff in pairs}
    used_tracks = set()
    chains = []
    for _, start, end in pairs:
        if start not in used_tracks:
            chain = [start]
            used_tracks.add(start)
            current = start
            next_track = connection_map.get(current)
            while next_track is not None and next_track not in used_tracks:
                chain.append(next_track)
                used_tracks.add(next_track)

                current = next_track
                next_track = connection_map.get(current)
            chains.append(chain)
    return chains 



#testing if the function works: testing for duplicate tracks in the list
trial_num = 5
all_tracks = [track for chain in generating_pairs_complex(trial_num) for track in chain]
duplicates = {t for t in all_tracks if all_tracks.count(t) > 1}
if duplicates: 
    print(f'Not working: There are duplicate tracks')
else: 
    print('Working: There are no duplicates')
# Out:
# Working: There are no duplicates

# %%
# Printing Trial 1 
print(generating_pairs_complex(1, radius = radius1))
# Out:
# [['Track_568', 'Track_576'], ['Track_687', 'Track_688', 'Track_689']]

# %% [markdown]
# Adding the pairs together in a new dataframe/dictionary and saving that dictionary in joblib.
# Adding all the non-paired/chained tracks.
#
# Problem is that if there is a track that begins in take-off and ends in landing, what then? It coppies the data double.
# First create a full list of al the tacks that need to merdge, with some lists of multiple (more than 2) tracks.
#
#
# duration: (1 m 45 s)

# %%
import joblib 
import os
merged_df = {}

for trial_num, trial_df in enumerate(df):
    trial_num += 1
    trial_key = f'Trial_{trial_num}'
    if trial_key not in merged_df:
        merged_df[trial_key] = pd.DataFrame(columns=['x', 'y', 'z', 'time'])
    # Make a set() of all the track names in a trial that are used for the apir/chain making
    used_track_names = set()

    chains = generating_pairs_complex(trial_num)
    for chain_idx, chain in enumerate(chains):
        for track in chain:
            used_track_names.add(track)
        merged_track_name = f"Merged_Chain_{chain_idx + 1}"
        merged_x = tuple(x for track in chain for x in df[trial_key].loc[track, 'x'])
        merged_y = tuple(y for track in chain for y in df[trial_key].loc[track, 'y'])
        merged_z = tuple(z for track in chain for z in df[trial_key].loc[track, 'z'])
        merged_time = tuple(t for track in chain for t in df[trial_key].loc[track, 'time'])

        merged_df[trial_key].at[f'{merged_track_name}', 'x'] = merged_x
        merged_df[trial_key].at[f'{merged_track_name}', 'y'] = merged_y
        merged_df[trial_key].at[f'{merged_track_name}', 'z'] = merged_z
        merged_df[trial_key].at[f'{merged_track_name}', 'time'] = merged_time
    
    for track in df[trial_key].index:
        if track not in used_track_names: 
            merged_df[trial_key].at[track, 'x'] = df[trial_key].loc[track, 'x']
            merged_df[trial_key].at[track, 'y'] = df[trial_key].loc[track, 'y']
            merged_df[trial_key].at[track, 'z'] = df[trial_key].loc[track, 'z']
            merged_df[trial_key].at[track, 'time'] = df[trial_key].loc[track, 'time']

        

dataset_path = '/Users/nubia/Desktop/Thesis_2.0/dataset'
save_path = os.path.join(dataset_path, file_name)
joblib.dump(merged_df, save_path)

print(f"Data saved to: {save_path}")
# Out:
# Data saved to: /Users/nubia/Desktop/Thesis_2.0/dataset/merged_df_boundary_0.01_radius_0.02.joblib
